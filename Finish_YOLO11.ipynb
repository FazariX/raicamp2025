# %% [markdown]
# # Setup YOLO11
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/requirements.txt) and check software and hardware.

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.75 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 33.1/112.6 GB disk)

# %% [markdown]
# # 1. Predict ( Test Setup YOLO11)
#
# YOLOv8 may be used directly in the Command Line Interface (CLI) with a `yolo` command for a variety of tasks and modes and accepts additional arguments, i.e. `imgsz=640`. See a full list of available `yolo` [arguments](https://docs.ultralytics.com/usage/cfg/) and other details in the [YOLO11 Predict Docs](https://docs.ultralytics.com/modes/train/).

# %%
# Run inference on an image with YOLOv11n
# !yolo predict model=yolo11n.pt source='https://ultralytics.com/images/bus.jpg'
# Out:
# ...
# 100% 5.35M/5.35M [00:00<00:00, 106MB/s]
# Ultralytics 8.3.75 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 238 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# ...
# 100% 134k/134k [00:00<00:00, 7.39MB/s]
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 81.0ms
# Speed: 14.8ms preprocess, 81.0ms inference, 390.3ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # 2. Add Zip Data Export YOLO11 for Roboflow

# %%
import zipfile
from google.colab import files

# %cd /content
uploaded = files.upload()
for filename in uploaded.keys():
  pass

zip_ref = zipfile.ZipFile(filename, 'r')
zip_ref.extractall("/content/")
# Out:
# /content
#      <input type="file" id="files-f0a77e91-7250-49bc-9b3c-732347c3ccf7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f0a77e91-7250-49bc-9b3c-732347c3ccf7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %% [markdown]
# # 3. Train Data Roboflow

# %%
# Validate YOLOv8n
# !yolo train model=yolo11n.pt data=data.yaml epochs=200 imgsz=640
# Out:
# Ultralytics 8.3.75 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# # 4. Test Model Training

# %%
# !yolo detect predict model=/content/runs/detect/train2/weights/best.pt conf=0.8 imgsz=640 source='/content/test/images/'
# Out:
# Ultralytics 8.3.75 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 238 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/3 /content/test/images/yt-qCY8_SQ93O8-0015_jpg.rf.523a2a0752d70e983abb8c170ab122be.jpg: 640x640 1 1, 10.4ms
# image 2/3 /content/test/images/yt-qCY8_SQ93O8-0018_jpg.rf.1a85571c55b735f69e5253ba7ceec619.jpg: 640x640 2 1s, 1 10, 9.0ms
# image 3/3 /content/test/images/yt-qCY8_SQ93O8-0022_jpg.rf.98d5ecb4dc8de09fecd6df05dd8b8310.jpg: 640x640 (no detections), 8.1ms
# Speed: 2.6ms preprocess, 9.2ms inference, 50.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict6
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # 5. Test Video for Model Ai

# %%
# !yolo detect predict model=/content/runs/detect/train2/weights/best.pt  conf=0.8 imgsz=640 source='/content/DataTestENV2.mp4'
# Out:
# Ultralytics 8.3.75 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 238 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
#
# video 1/1 (frame 1/2392) /content/DataTestENV2.mp4: 640x384 1 1, 74.0ms
# video 1/1 (frame 2/2392) /content/DataTestENV2.mp4: 640x384 1 1, 11.8ms
# video 1/1 (frame 3/2392) /content/DataTestENV2.mp4: 640x384 1 1, 9.2ms
# video 1/1 (frame 4/2392) /content/DataTestENV2.mp4: 640x384 1 1, 10.7ms
# video 1/1 (frame 5/2392) /content/DataTestENV2.mp4: 640x384 (no detections), 12.5ms
# video 1/1 (frame 6/2392) /content/DataTestENV2.mp4: 640x384 1 1, 10.8ms
# video 1/1 (frame 7/2392) /content/DataTestENV2.mp4: 640x384 1 1, 9.8ms
# video 1/1 (frame 8/2392) /content/DataTestENV2.mp4: 640x384 1 1, 11.9ms
# video 1/1 (frame 9/2392) /content/DataTestENV2.mp4: 640x384 (no detections), 9.9ms
# video 1/1 (frame 10/2392) /content/DataTestENV2.mp4: 640x384 (no detections), 12.0ms
# ...
